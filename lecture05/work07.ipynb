# %%
"""
    mylegendre(n, x)

Calculate Legendre polynomial P_n(x) using the recurrence relation    
(n+1)P_{n+1}(x) = (2*n+1)*x*P_n(x) - n*P_{n-1}(x), and P_0(x) = 1, P_1(x) = x
"""
function mylegendre(n, x)
    pp = 1
    if n == 0
        return pp
end
    pc = x
    if n == 1
        return pc
    end

    for n = 1:(n-1)
        # pn = (2*n + 1)/(n + 1) * x * pc - n/(n + 1) * pp
        # pp = pc
        # pc = pn
        pc, pp = (2*n + 1)/(n + 1) * x * pc - n/(n + 1) * pp, pc
    end

    return pc
end
# Out:
# mylegendre

# %%
@show mylegendre(3, 0.0);   # must be 0
@show mylegendre(3, -1.0);  # must be -1
# Out:
# mylegendre(3, 0.0) = -0.0
# mylegendre(3, -1.0) = -1.0

# %%
@time mylegendre(1, 1.0)
# Out:
#   0.000000 seconds
# 1.0

# %%
@time mylegendre(51, -1.0)
# Out:
#   0.000001 seconds
# -0.9999999999999952

# %%
np = 100
x = range(-1.0, 1.0, np);

# %%
using PyPlot

# %%
for n = [2, 3, 5, 7]
    plot(x, mylegendre.(n, x), label=L"P_{%$n}")
end

grid(true)
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x722830ad3f20>
